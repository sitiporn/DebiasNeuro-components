# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import torch
import pickle
import numpy as np
from collections import Counter
import glob
import collections
# read top neurons
import yaml 
import sys  
sys.path.append('../')
from my_package.cma import get_topk
import os
# Out:
# /tmp/ipykernel_234473/3195766934.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %%
import seaborn as sns
import pandas as pd 
top_neuron_path = '../../pickles/top_neurons/'
masking_mode = 'percent'
key = 0.05
data = {}
df = {}

# %%
# method_names = ['separation_replace_intervention_recent_baseline', 'nie_recent_baseline']
# interventions = ['Null', 'inject_bias']
method_names = ['nie_recent_baseline','nie_recent_baseline']
interventions = ['High-overlap','Low-overlap']
seed = 1548
fig, axes = plt.subplots(1, 2, figsize=(15, 5), sharey=True)
fig.suptitle(f'Baseline-MNLI-{seed}')


x_layer = []
y_nie = []
line_type = []
top_neurons = {}

for method_name, intervention in zip(method_names, interventions):
    path = os.path.join(top_neuron_path, method_name)
    path = os.path.join(path,f'top_neuron_layer_each_{seed}_{masking_mode}_{intervention}_all_layers.pickle')
    with open(path, 'rb') as handle: top_neurons[intervention] = pickle.load(handle)
    current_dataset = f'Averaged Counterfactual'
    for layer in top_neurons[intervention][key].keys():
        x_layer.extend([ int(pos.split('-')[1]) for pos, nie in top_neurons[intervention][key][layer].items()])
        y_nie.extend([float(nie) for pos, nie in top_neurons[intervention][key][layer].items()])
        line_type.extend([intervention] * len(top_neurons[intervention][key][layer])  )
    


data = {'Layer index': x_layer,
        'Indirect effects of top neurons':  y_nie,
         'Treatments': line_type}

df = pd.DataFrame(data=data) 
sns.set_theme(style="darkgrid")
sns.lineplot(ax=axes[0], data=df, x="Layer index", y="Indirect effects of top neurons",  hue="Treatments", style="Treatments", palette=['blue', 'red'])
axes[0].set_title(current_dataset)

###

# method_names = ['separation_replace_intervention_recent_baseline', 'nie_recent_baseline']
# interventions = ['Null', 'inject_bias']
method_names = ['nie_recent_baseline','nie_recent_baseline']
interventions = ['High-overlap','Low-overlap']

seed = 1548
x_layer = []
y_nie = []
line_type = []
top_neurons = {}

for method_name, intervention in zip(method_names, interventions):
    path = os.path.join(top_neuron_path, method_name)
    path = os.path.join(path,f'top_neuron_layer_each_{seed}_{masking_mode}_{intervention}_all_layers_class_level.pickle')
    with open(path, 'rb') as handle: top_neurons[intervention] = pickle.load(handle)
    current_dataset = f'Intervene Class Wise'
    for layer in top_neurons[intervention][key].keys():
        x_layer.extend([ int(pos.split('-')[1]) for pos, nie in top_neurons[intervention][key][layer].items()])
        y_nie.extend([float(nie) for pos, nie in top_neurons[intervention][key][layer].items()])
        line_type.extend([intervention] * len(top_neurons[intervention][key][layer])  )
    


data = {'Layer index': x_layer,
        'Indirect effects of top neurons':  y_nie,
         'Treatments': line_type}

df = pd.DataFrame(data=data) 
sns.set_theme(style="darkgrid")
sns.lineplot(ax=axes[1], data=df, x="Layer index", y="Indirect effects of top neurons",  hue="Treatments", style="Treatments", palette=['blue', 'red'])
axes[1].set_title(current_dataset)
# Out:
# Text(0.5, 1.0, 'Intervene Class Wise')

# %%
# method_names = ['separation_replace_intervention_recent_baseline', 'nie_recent_baseline']
# interventions = ['Null', 'inject_bias']
method_names = ['nie_recent_baseline','nie_recent_baseline']
interventions = ['High-overlap','Low-overlap']
seed = 3099
fig, axes = plt.subplots(1, 2, figsize=(15, 5), sharey=True)
fig.suptitle(f'Baseline-MNLI-{seed}')


x_layer = []
y_nie = []
line_type = []
top_neurons = {}

for method_name, intervention in zip(method_names, interventions):
    path = os.path.join(top_neuron_path, method_name)
    path = os.path.join(path,f'top_neuron_layer_each_{seed}_{masking_mode}_{intervention}_all_layers.pickle')
    with open(path, 'rb') as handle: top_neurons[intervention] = pickle.load(handle)
    current_dataset = f'Averaged Counterfactual'
    for layer in top_neurons[intervention][key].keys():
        x_layer.extend([ int(pos.split('-')[1]) for pos, nie in top_neurons[intervention][key][layer].items()])
        y_nie.extend([float(nie) for pos, nie in top_neurons[intervention][key][layer].items()])
        line_type.extend([intervention] * len(top_neurons[intervention][key][layer])  )
    


data = {'Layer index': x_layer,
        'Indirect effects of top neurons':  y_nie,
         'Treatments': line_type}

df = pd.DataFrame(data=data) 
sns.set_theme(style="darkgrid")
sns.lineplot(ax=axes[0], data=df, x="Layer index", y="Indirect effects of top neurons",  hue="Treatments", style="Treatments", palette=['blue', 'red'])
axes[0].set_title(current_dataset)

###

# method_names = ['separation_replace_intervention_recent_baseline', 'nie_recent_baseline']
# interventions = ['Null', 'inject_bias']
method_names = ['nie_recent_baseline','nie_recent_baseline']
interventions = ['High-overlap','Low-overlap']

seed = 3099
x_layer = []
y_nie = []
line_type = []
top_neurons = {}

for method_name, intervention in zip(method_names, interventions):
    path = os.path.join(top_neuron_path, method_name)
    path = os.path.join(path,f'top_neuron_layer_each_{seed}_{masking_mode}_{intervention}_all_layers_class_level.pickle')
    with open(path, 'rb') as handle: top_neurons[intervention] = pickle.load(handle)
    current_dataset = f'Intervene Class Wise'
    for layer in top_neurons[intervention][key].keys():
        x_layer.extend([ int(pos.split('-')[1]) for pos, nie in top_neurons[intervention][key][layer].items()])
        y_nie.extend([float(nie) for pos, nie in top_neurons[intervention][key][layer].items()])
        line_type.extend([intervention] * len(top_neurons[intervention][key][layer])  )
    


data = {'Layer index': x_layer,
        'Indirect effects of top neurons':  y_nie,
         'Treatments': line_type}

df = pd.DataFrame(data=data) 
sns.set_theme(style="darkgrid")
sns.lineplot(ax=axes[1], data=df, x="Layer index", y="Indirect effects of top neurons",  hue="Treatments", style="Treatments", palette=['blue', 'red'])
axes[1].set_title(current_dataset)
# Out:
# Text(0.5, 1.0, 'Intervene Class Wise')

# %%
# method_names = ['separation_replace_intervention_recent_baseline', 'nie_recent_baseline']
# interventions = ['Null', 'inject_bias']
method_names = ['nie_recent_baseline','nie_recent_baseline']
interventions = ['High-overlap','Low-overlap']
seed = 3785
fig, axes = plt.subplots(1, 2, figsize=(15, 5), sharey=True)
fig.suptitle(f'Baseline-MNLI-{seed}')


x_layer = []
y_nie = []
line_type = []
top_neurons = {}

for method_name, intervention in zip(method_names, interventions):
    path = os.path.join(top_neuron_path, method_name)
    path = os.path.join(path,f'top_neuron_layer_each_{seed}_{masking_mode}_{intervention}_all_layers.pickle')
    with open(path, 'rb') as handle: top_neurons[intervention] = pickle.load(handle)
    current_dataset = f'Averaged Counterfactual'
    for layer in top_neurons[intervention][key].keys():
        x_layer.extend([ int(pos.split('-')[1]) for pos, nie in top_neurons[intervention][key][layer].items()])
        y_nie.extend([float(nie) for pos, nie in top_neurons[intervention][key][layer].items()])
        line_type.extend([intervention] * len(top_neurons[intervention][key][layer])  )
    


data = {'Layer index': x_layer,
        'Indirect effects of top neurons':  y_nie,
         'Treatments': line_type}

df = pd.DataFrame(data=data) 
sns.set_theme(style="darkgrid")
sns.lineplot(ax=axes[0], data=df, x="Layer index", y="Indirect effects of top neurons",  hue="Treatments", style="Treatments", palette=['blue', 'red'])
axes[0].set_title(current_dataset)

###

# method_names = ['separation_replace_intervention_recent_baseline', 'nie_recent_baseline']
# interventions = ['Null', 'inject_bias']
method_names = ['nie_recent_baseline','nie_recent_baseline']
interventions = ['High-overlap','Low-overlap']

seed = 3785
x_layer = []
y_nie = []
line_type = []
top_neurons = {}

for method_name, intervention in zip(method_names, interventions):
    path = os.path.join(top_neuron_path, method_name)
    path = os.path.join(path,f'top_neuron_layer_each_{seed}_{masking_mode}_{intervention}_all_layers_class_level.pickle')
    with open(path, 'rb') as handle: top_neurons[intervention] = pickle.load(handle)
    current_dataset = f'Intervene Class Wise'
    for layer in top_neurons[intervention][key].keys():
        x_layer.extend([ int(pos.split('-')[1]) for pos, nie in top_neurons[intervention][key][layer].items()])
        y_nie.extend([float(nie) for pos, nie in top_neurons[intervention][key][layer].items()])
        line_type.extend([intervention] * len(top_neurons[intervention][key][layer])  )
    


data = {'Layer index': x_layer,
        'Indirect effects of top neurons':  y_nie,
         'Treatments': line_type}

df = pd.DataFrame(data=data) 
sns.set_theme(style="darkgrid")
sns.lineplot(ax=axes[1], data=df, x="Layer index", y="Indirect effects of top neurons",  hue="Treatments", style="Treatments", palette=['blue', 'red'])
axes[1].set_title(current_dataset)
# Out:
# Text(0.5, 1.0, 'Intervene Class Wise')

# %%
# method_names = ['separation_replace_intervention_recent_baseline', 'nie_recent_baseline']
# interventions = ['Null', 'inject_bias']
method_names = ['nie_recent_baseline','nie_recent_baseline']
interventions = ['High-overlap','Low-overlap']
seed = 3990
fig, axes = plt.subplots(1, 2, figsize=(15, 5), sharey=True)
fig.suptitle(f'Baseline-MNLI-{seed}')


x_layer = []
y_nie = []
line_type = []
top_neurons = {}

for method_name, intervention in zip(method_names, interventions):
    path = os.path.join(top_neuron_path, method_name)
    path = os.path.join(path,f'top_neuron_layer_each_{seed}_{masking_mode}_{intervention}_all_layers.pickle')
    with open(path, 'rb') as handle: top_neurons[intervention] = pickle.load(handle)
    current_dataset = f'Averaged Counterfactual'
    for layer in top_neurons[intervention][key].keys():
        x_layer.extend([ int(pos.split('-')[1]) for pos, nie in top_neurons[intervention][key][layer].items()])
        y_nie.extend([float(nie) for pos, nie in top_neurons[intervention][key][layer].items()])
        line_type.extend([intervention] * len(top_neurons[intervention][key][layer])  )
    


data = {'Layer index': x_layer,
        'Indirect effects of top neurons':  y_nie,
         'Treatments': line_type}

df = pd.DataFrame(data=data) 
sns.set_theme(style="darkgrid")
sns.lineplot(ax=axes[0], data=df, x="Layer index", y="Indirect effects of top neurons",  hue="Treatments", style="Treatments", palette=['blue', 'red'])
axes[0].set_title(current_dataset)

###

# method_names = ['separation_replace_intervention_recent_baseline', 'nie_recent_baseline']
# interventions = ['Null', 'inject_bias']
method_names = ['nie_recent_baseline','nie_recent_baseline']
interventions = ['High-overlap','Low-overlap']

seed = 3990
x_layer = []
y_nie = []
line_type = []
top_neurons = {}

for method_name, intervention in zip(method_names, interventions):
    path = os.path.join(top_neuron_path, method_name)
    path = os.path.join(path,f'top_neuron_layer_each_{seed}_{masking_mode}_{intervention}_all_layers_class_level.pickle')
    with open(path, 'rb') as handle: top_neurons[intervention] = pickle.load(handle)
    current_dataset = f'Intervene Class Wise'
    for layer in top_neurons[intervention][key].keys():
        x_layer.extend([ int(pos.split('-')[1]) for pos, nie in top_neurons[intervention][key][layer].items()])
        y_nie.extend([float(nie) for pos, nie in top_neurons[intervention][key][layer].items()])
        line_type.extend([intervention] * len(top_neurons[intervention][key][layer])  )
    


data = {'Layer index': x_layer,
        'Indirect effects of top neurons':  y_nie,
         'Treatments': line_type}

df = pd.DataFrame(data=data) 
sns.set_theme(style="darkgrid")
sns.lineplot(ax=axes[1], data=df, x="Layer index", y="Indirect effects of top neurons",  hue="Treatments", style="Treatments", palette=['blue', 'red'])
axes[1].set_title(current_dataset)
# Out:
# Text(0.5, 1.0, 'Intervene Class Wise')

# %%
# method_names = ['separation_replace_intervention_recent_baseline', 'nie_recent_baseline']
# interventions = ['Null', 'inject_bias']
method_names = ['nie_recent_baseline','nie_recent_baseline']
interventions = ['High-overlap','Low-overlap']
seed = 409
fig, axes = plt.subplots(1, 2, figsize=(15, 5), sharey=True)
fig.suptitle(f'Baseline-MNLI-{seed}')


x_layer = []
y_nie = []
line_type = []
top_neurons = {}

for method_name, intervention in zip(method_names, interventions):
    path = os.path.join(top_neuron_path, method_name)
    path = os.path.join(path,f'top_neuron_layer_each_{seed}_{masking_mode}_{intervention}_all_layers.pickle')
    with open(path, 'rb') as handle: top_neurons[intervention] = pickle.load(handle)
    current_dataset = f'Averaged Counterfactual'
    for layer in top_neurons[intervention][key].keys():
        x_layer.extend([ int(pos.split('-')[1]) for pos, nie in top_neurons[intervention][key][layer].items()])
        y_nie.extend([float(nie) for pos, nie in top_neurons[intervention][key][layer].items()])
        line_type.extend([intervention] * len(top_neurons[intervention][key][layer])  )
    


data = {'Layer index': x_layer,
        'Indirect effects of top neurons':  y_nie,
         'Treatments': line_type}

df = pd.DataFrame(data=data) 
sns.set_theme(style="darkgrid")
sns.lineplot(ax=axes[0], data=df, x="Layer index", y="Indirect effects of top neurons",  hue="Treatments", style="Treatments", palette=['blue', 'red'])
axes[0].set_title(current_dataset)

###

# method_names = ['separation_replace_intervention_recent_baseline', 'nie_recent_baseline']
# interventions = ['Null', 'inject_bias']
method_names = ['nie_recent_baseline','nie_recent_baseline']
interventions = ['High-overlap','Low-overlap']

seed = 409
x_layer = []
y_nie = []
line_type = []
top_neurons = {}

for method_name, intervention in zip(method_names, interventions):
    path = os.path.join(top_neuron_path, method_name)
    path = os.path.join(path,f'top_neuron_layer_each_{seed}_{masking_mode}_{intervention}_all_layers_class_level.pickle')
    with open(path, 'rb') as handle: top_neurons[intervention] = pickle.load(handle)
    current_dataset = f'Intervene Class Wise'
    for layer in top_neurons[intervention][key].keys():
        x_layer.extend([ int(pos.split('-')[1]) for pos, nie in top_neurons[intervention][key][layer].items()])
        y_nie.extend([float(nie) for pos, nie in top_neurons[intervention][key][layer].items()])
        line_type.extend([intervention] * len(top_neurons[intervention][key][layer])  )
    


data = {'Layer index': x_layer,
        'Indirect effects of top neurons':  y_nie,
         'Treatments': line_type}

df = pd.DataFrame(data=data) 
sns.set_theme(style="darkgrid")
sns.lineplot(ax=axes[1], data=df, x="Layer index", y="Indirect effects of top neurons",  hue="Treatments", style="Treatments", palette=['blue', 'red'])
axes[1].set_title(current_dataset)
# Out:
# Text(0.5, 1.0, 'Intervene Class Wise')
